# %% [markdown]
# # Быстрый обзор данных
# Я выбрал для аналиа [https://www.kaggle.com/datasets/jayaantanaath/student-habits-vs-academic-performance](https://www.kaggle.com/datasets/jayaantanaath/student-habits-vs-academic-performance) "Perfect for EDA". Сначала, конечно я выбрал другой, но там не было null, и или мне самому удалять или искать другой датасэт. Я выбрал 2 вариант.

# %%
import pandas
df = pandas.read_csv('dataset.csv')
df.head(11)
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0             1.1            No                   85.0          8.0
# ...

# %%
df.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.describe(include="str")
# Out:
#        student_id  gender part_time_job diet_quality parental_education_level  \
# count        1000    1000          1000         1000                      909
# unique       1000       3             2            3                        3
# top         S1000  Female            No         Fair              High School
# freq            1     481           785          437                      392
#
#        internet_quality extracurricular_participation
# count              1000                          1000
# unique                3                             2
# top                Good                            No
# freq                447                           682

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# student_id                           str
# age                                int64
# gender                               str
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                        str
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                         str
# exercise_frequency                 int64
# parental_education_level             str
# internet_quality                     str
# mental_health_rating               int64
# extracurricular_participation        str
# exam_score                       float64
# dtype: object

# %% [markdown]
# # Пропуски и очистка
# Я посмотрел файл и "None" считается как NaN (это 10 строка).

# %%
df.dropna().shape
# Out:
# (909, 16)

# %% [markdown]
# df.dropna() просто удалил эти 91 строк

# %%
df.fillna( "No education").head(11)
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0             1.1            No                   85.0          8.0
# ...

# %% [markdown]
# В этом случае лучше заменить константой по типу "No education". Как минимум, потому что это строковое значение (на него надо, наверное, писать свои среднее и медиану). Среднее или медиана, помоему, лучше использовать, если это надо сохранить какое-то колличество данных, которые не нулевые.

# %% [markdown]
# # Мода
# Если считаем, что "None" -- это не полученное значение, то можно заменить модой.

# %%
df.fillna({"parental_education_level": df['parental_education_level'].mode()[0]}).head(11)
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0             1.1            No                   85.0          8.0
# ...

# %% [markdown]
# # Расширенная статистика

# %%
df_nums = df.select_dtypes('number')
df_nums
# Out:
#      age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23                  0.0                 1.2            1.1
# 1     20                  6.9                 2.8            2.3
# 2     21                  1.4                 3.1            1.3
# 3     23                  1.0                 3.9            1.0
# 4     19                  5.0                 4.4            0.5
# ..   ...                  ...                 ...            ...
# 995   21                  2.6                 0.5            1.6
# 996   17                  2.9                 1.0            2.4
# 997   20                  3.0                 2.6            1.3
# 998   24                  5.4                 4.1            1.1
# 999   19                  4.3                 2.9            1.9
#
#      attendance_percentage  sleep_hours  exercise_frequency  \
# 0                     85.0          8.0                   6
# 1                     97.3          4.6                   6
# ...

# %%
df_nums.min()
# Out:
# age                      17.0
# study_hours_per_day       0.0
# social_media_hours        0.0
# netflix_hours             0.0
# attendance_percentage    56.0
# sleep_hours               3.2
# exercise_frequency        0.0
# mental_health_rating      1.0
# exam_score               18.4
# dtype: float64

# %%
df_nums.max()
# Out:
# age                       24.0
# study_hours_per_day        8.3
# social_media_hours         7.2
# netflix_hours              5.4
# attendance_percentage    100.0
# sleep_hours               10.0
# exercise_frequency         6.0
# mental_health_rating      10.0
# exam_score               100.0
# dtype: float64

# %%
df_nums.median()
# Out:
# age                      20.0
# study_hours_per_day       3.5
# social_media_hours        2.5
# netflix_hours             1.8
# attendance_percentage    84.4
# sleep_hours               6.5
# exercise_frequency        3.0
# mental_health_rating      5.0
# exam_score               70.5
# dtype: float64

# %%
df_nums.mean()
# Out:
# age                      20.4980
# study_hours_per_day       3.5501
# social_media_hours        2.5055
# netflix_hours             1.8197
# attendance_percentage    84.1317
# sleep_hours               6.4701
# exercise_frequency        3.0420
# mental_health_rating      5.4380
# exam_score               69.6015
# dtype: float64

# %%
df_nums.mode()
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   20                  3.5                 3.1            0.0
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                  100.0          6.5                   3
#
#    mental_health_rating  exam_score
# 0                     4       100.0

# %%
df_nums.quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#         age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0.05  17.00                  1.1               0.595          0.000
# 0.25  18.75                  2.6               1.700          1.000
# 0.50  20.00                  3.5               2.500          1.800
# 0.75  23.00                  4.5               3.300          2.525
# 0.95  24.00                  6.0               4.500          3.600
#
#       attendance_percentage  sleep_hours  exercise_frequency  \
# 0.05                 67.595        4.595                 0.0
# 0.25                 78.000        5.600                 1.0
# 0.50                 84.400        6.500                 3.0
# 0.75                 91.025        7.300                 5.0
# 0.95                100.000        8.500                 6.0
#
#       mental_health_rating  exam_score
# 0.05                   1.0      41.700
# 0.25                   3.0      58.475
# 0.50                   5.0      70.500
# ...

# %%
df_nums.var()
# Out:
# age                        5.327323
# study_hours_per_day        2.157638
# social_media_hours         1.374574
# netflix_hours              1.155878
# attendance_percentage     88.345831
# sleep_hours                1.504000
# exercise_frequency         4.102338
# mental_health_rating       8.108264
# exam_score               285.223591
# dtype: float64

# %%
df_nums.skew()
# Out:
# age                      0.008437
# study_hours_per_day      0.054253
# social_media_hours       0.119805
# netflix_hours            0.237154
# attendance_percentage   -0.237810
# sleep_hours              0.091484
# exercise_frequency      -0.031923
# mental_health_rating     0.037811
# exam_score              -0.156351
# dtype: float64

# %%
df_nums.kurtosis()
# Out:
# age                     -1.218994
# study_hours_per_day     -0.055652
# social_media_hours      -0.094082
# netflix_hours           -0.432858
# attendance_percentage   -0.390711
# sleep_hours             -0.214309
# exercise_frequency      -1.276526
# mental_health_rating    -1.188602
# exam_score              -0.419908
# dtype: float64

# %% [markdown]
# Если не знать определения, то вообще не интуитивно, что это за числа. kurtosis - насколько острее нормального распределения. skewness - на сколько оно сдвинуто вправо. *наверное* variance - насколько сильно отличается от константной.

# %% [markdown]
# # Фичи: Энкодинг и Инжиниринг

# %%
pandas.get_dummies(df,drop_first=1,columns=["parental_education_level"])
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# Target Encoding не очень подходит. Сделаем label encoding

# %%
print ('do:\n', df)
df['internet_quality_encoded'] = df['internet_quality'].astype('category').cat.codes
df=df.drop('internet_quality',axis=1)
print ('posle:\n',df)
# Out:
# do:
#      student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# # Визуализация

# %%
from matplotlib import pyplot as plt
import seaborn as sb
import plotly.express as px

# %%
sb.histplot(df['attendance_percentage'])
# Out:
# <Axes: xlabel='attendance_percentage', ylabel='Count'>

# %%
plt.hist(df['age'])
plt.xlabel('age')
plt.show()

# %%
px.histogram(df['age'])

# %%
px.histogram(df['exam_score'])

# %% [markdown]
# plotly мне понравился побольше, он нормально работает с целыми данными

# %% [markdown]
# # Scatter

# %%
plt.scatter(df['study_hours_per_day'],df['exam_score'])

# %%
sb.scatterplot(x=df['study_hours_per_day'],y=df['exam_score'])
# Out:
# <Axes: xlabel='study_hours_per_day', ylabel='exam_score'>

# %%
px.scatter(x=df['study_hours_per_day'],y=df['exam_score'])

# %% [markdown]
# # Box plot

# %%
plt.boxplot(df['attendance_percentage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ea34282d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ea34282fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ea34282c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ea34283250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ea34283390>],
#  'means': []}

# %%
sb.boxplot(df['attendance_percentage'])
# Out:
# <Axes: ylabel='attendance_percentage'>

# %%
px.box(df['attendance_percentage'])

# %% [markdown]
# #  Bar/count plot

# %%
sb.countplot(df['parental_education_level'])
# Out:
# <Axes: xlabel='count', ylabel='parental_education_level'>

# %%
sb.barplot(x=df['parental_education_level'],y=df['mental_health_rating'])
# Out:
# <Axes: xlabel='parental_education_level', ylabel='mental_health_rating'>

# %%
plt.bar(df['age'].value_counts().index,df['age'].value_counts().values)
# Out:
# <BarContainer object of 8 artists>

# %%
px.bar(df['age'].value_counts(),df['age'].value_counts())

# %% [markdown]
# # Heatmap

# %%
sb.heatmap(df.select_dtypes('number').corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# # Итоговые выводы
# - датасэт какой-то странный (корелляция только с экзаменом(таргетом), остальное между собой не кореллирует)
# - выбросов вроде нет
# - модель могу предположить только линейную для предсказывания экзамена
# - в общем пользовался обзор ии от google
